# %% [markdown]
# # Relativistic motion of charged particles in ideal dipole field of planet Earth using Boris C method

# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
#defining the constants
c = 299792458.0 # [m/s]  speed of light
Re = 6378137.0 # [m] earth's radius
B_0 = 3.07e-5
m_p = 1.6726219e-27 # [kg]  mass of proton
m_e = 9.10938356e-31 # [kg]  mass of electron
qe = 1.6021766210e-19 # [C]  elemantary charge
sinphi = np.sin(11.7*np.pi/180.0) # 11.7 degrees between magnetic and rotational axis
cosphi = np.cos(11.7*np.pi/180.0)

# %%
# defining an ideal dipole field of earth
# given in 10.1016@j.asr.2020.10.020.pdf eqn 4

def BP(R): 
    denom = (R[0]**2.0 + R[1]**2.0 + R[2]**2.0)**2.5
    BPx = -(B_0*Re**3)*((3.0*R[0]*R[2]*cosphi) + (3.0*R[0]*R[1]*sinphi))/denom
    BPy = -(B_0*Re**3)*((3.0*R[1]*R[2]*cosphi) + (2.0*sinphi*(R[1]**2.0)) - (sinphi*(R[0]**2.0)) - (sinphi*(R[2]**2.0)))/denom
    BPz = -(B_0*Re**3)*((2.0*cosphi*(R[2]**2.0)) - (cosphi*(R[0]**2.0)) - (cosphi*(R[1]**2.0)) + (3.0*R[2]*R[1]*sinphi))/denom  
    BP = np.array([BPx, BPy, BPz])
    return BP

# %%
dt = 0.001 # integration step  
ts = 20.0 # simulation duration
n_step = int(ts/dt) # number of steps

# %%
t = np.zeros(n_step) # initializing
rvek = np.zeros((len(t), 3))
vvek = np.zeros((len(t), 3))
gamma = np.empty(len(t))
gamma_plot = np.empty(len(t))   #Storing gamma for plotting

# %%
# for particle type protons
m = 1.0*m_p  
q = 1.0*qe

# %%
rvek[0, :] = np.array([2.5, 0.0, 0.0])*Re
vvek[0, :] = np.array([0.0, 0.616*0.5*c, 0.616*0.866*c])
E = np.array([0.0, 0.0, 0.0])

# %%
# the equation no. commented here refer to the equations in my report for comparison
kinetic_init = m * 0.5 * np.linalg.norm(vvek[0, :]) ** 2.0
for i in range(1,n_step):
    R = rvek[i-1, :]
    v = vvek[i-1,:]
    gamma = 1.0/(np.sqrt(1-(np.dot(v,v)/c**2)))   #eqn 3
    u = v * gamma
    R_minus = R + (dt*u)/(2*gamma)   #eqn 4
    
   
    B = BP(R_minus)
    mod_B = (np.sqrt(B[0]**2.0 + B[1]**2.0 + B[2]**2.0))
    b = B/mod_B
    
    u_minus = u + (q*dt/(2.0*m))*(E)   #eqn 5
    g_minus = np.sqrt(1+(np.dot(u_minus,u_minus)/c**2))   #eqn 9
    theta = (q*dt*mod_B)/(m*g_minus)    #eqn 8
    u_minus_pl = np.dot(u_minus, b)*b    #eqn 15
    u_prime = u_minus_pl+ ((u_minus - u_minus_pl)*np.cos(theta)) + (np.cross(u_minus,b)*np.sin(theta))   #eqn 16
    u_plus = u_prime + (q*dt/(2.0*m))*(E)   #eqn 7
    g_plus = np.sqrt(1+(np.dot(u_plus,u_plus)/c**2))
    v_plus = u_plus/g_plus
    R_plus = R_minus + (dt*u_plus)/(2*g_plus)   #eqn 14
    
    vvek[i] = v_plus
    rvek[i] = R_plus
    gamma_plot[i] = g_plus
    t[i] = dt*i
    
#    print(t[i],gamma_plot[i])
kinetic_final = m * 0.5 * np.linalg.norm(vvek[-1, :]) ** 2.0
ans = abs(kinetic_init - kinetic_final)/kinetic_init
print(ans)
# Out:
# 9.063561054620503e-16

# %%
# graphical representation
fig = plt.figure() 
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('auto')
ax.grid(False)
u, v = np.mgrid[0:2*np.pi:50j, 0:np.pi:50j] # Earth as a ball
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)
ax.plot_wireframe(x, y, z, color = "blue")
plt.xlabel("$x[R_T]$")
plt.ylabel("$y[R_T]$")
ax.set_zlabel("$z[R_T]$")
plt.axis('on')
plt.plot(rvek[:, 0]/Re, rvek[:, 1]/Re, rvek[:, 2]/Re, color = 'green')
plt.show()

# %%
# graphical representation
fig = plt.figure() 
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('auto')
plt.xlabel("$x[R_T]$")
plt.ylabel("$y[R_T]$")
ax.set_zlabel("$z[R_T]$")
plt.axis('on')
plt.plot(rvek[:, 0]/Re, rvek[:, 1]/Re, rvek[:, 2]/Re, color = 'green')
plt.show()

# %%
plt.scatter(t,gamma_plot, color='pink', s=2)
plt.ylim(1.2675, 1.2700)
plt.xlabel('Time')
plt.ylabel('Lorentz factor')
# Out:
# Text(0, 0.5, 'Lorentz factor')
