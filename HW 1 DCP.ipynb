# %% [markdown]
# Use NonERL_MagVerle to see how electrons, protons and alpha particles move in constant Bz = 5uG (micro Gauss). Init. values: x_0=y_0=z_0=0, V_x = 0, V_y, V_z = RANDOM. Calculate abs(Efin-Ein)/Ein. Modify T_sim, dt, T_smp, d

# %% [markdown]
# ### For protons

# %%
# Based on V. Zekovic & B. Arbutina, Nucl. Part. Phys. Proc. 297-299, 53-57 (2018) but with different numerical algorithm
# Magnetic Verlet


import numpy as np
import matplotlib.pyplot as plt
import PVREDNOSTI, IZLAZ, DEFPOLJA # Input files (PVREDNOSTI: initial conditions are there; IZLAZ: output to be shown in graph is there; DEFPOLJA: field definitions are there)

#############################
# Input parameters
#############################

N = 1 # we use only one particle

T_sim = 300.0 # simulation duration [s]
dt = 0.1 # time step
T_smp = 5.0 # times step for graphical representation

##########################
# definitions of variables
##########################

l = 0
q = np.zeros(N)
m = np.zeros(N)
x = np.zeros(N)
y = np.zeros(N)
z = np.zeros(N)
vx = np.zeros(N)
vy = np.zeros(N)
vz = np.zeros(N)
EPx = 0.0
EPy = 0.0
EPz = 0.0
BPx = 0.0
BPy = 0.0
BPz = 0.0   
pomx = np.zeros(N)
pomy = np.zeros(N)
pomz = np.zeros(N)

#################
# initialization
#################

t = 0.0
 
q, m, x, y, z, vx, vy, vz = PVREDNOSTI.puslovi_p(N, np)

BPx, BPy, BPz, EPx, EPy, EPz = DEFPOLJA.const_B(x, y, z, t)

fig, sp1, sp2 = IZLAZ.init_plots(plt)


xx = np.zeros(60001)
yy = np.zeros(60001)
zz = np.zeros(60001)

ii = 0

xx[ii] = x
yy[ii] = y
zz[ii] = z


###############
# Main loop
###############
# See
# https://aapt.scitation.org/doi/10.1119/10.0001876
# https://arxiv.org/abs/2008.11810
# https://www.compadre.org/PICUP/resources/Numerical-Integration/

kinetickainit = m*0.5*(vx**2.0 + vy**2.0 + vz**2.0)

while t < (T_sim - dt):

    t = t + dt	

    pomx = vx + ((q*dt*0.5/m)*(EPx + (vy*BPz) - (BPy*vz)))       #eqn corresponding to d
    pomy = vy + ((q*dt*0.5/m)*(EPy + (vz*BPx) - (BPz*vx)))
    pomz = vz + ((q*dt*0.5/m)*(EPz + (vx*BPy) - (BPx*vy)))

    x = x + (pomx*dt)      #eqn 39
    y = y + (pomy*dt)
    z = z + (pomz*dt)
    

    BPx, BPy, BPz, EPx, EPy, EPz = DEFPOLJA.const_B(x, y, z, t)
    #print(x)
    pomx = pomx + ((q*dt*0.5/m)*EPx)
    pomy = pomy + ((q*dt*0.5/m)*EPy)
    pomz = pomz + ((q*dt*0.5/m)*EPz)

    # below equarions correspond to eqn 40 in my report
    vx = ((1.0 + (((q*dt*0.5/m)**2.0)*(BPx**2.0 + BPy**2.0 + BPz**2.0)))**(-1.0))*(pomx + ((q*dt*0.5/m)*(pomy*BPz - pomz*BPy)) + (((q*dt*0.5/m)**2.0)*BPx*(pomx*BPx + pomy*BPy + pomz*BPz)))

    vy = ((1.0 + (((q*dt*0.5/m)**2.0)*(BPx**2.0 + BPy**2.0 + BPz**2.0)))**(-1.0))*(pomy + ((q*dt*0.5/m)*(pomz*BPx - pomx*BPz)) + (((q*dt*0.5/m)**2.0)*BPy*(pomx*BPx + pomy*BPy + pomz*BPz))) 

    vz = ((1.0 + (((q*dt*0.5/m)**2.0)*(BPx**2.0 + BPy**2.0 + BPz**2.0)))**(-1.0))*(pomz + ((q*dt*0.5/m)*(pomx*BPy - pomy*BPx)) + (((q*dt*0.5/m)**2.0)*BPz*(pomx*BPx + pomy*BPy + pomz*BPz)))

    ii = ii + 1
    xx[ii] = x
    yy[ii] = y
    zz[ii] = z 
    ###################################
    # show in graph
    ###################################

    l += 1

    if l*dt >= T_smp:

        l = 0.0
        IZLAZ.write_plots(sp1, sp2, plt, x, y, z, t, T_sim) # show in real time

kinetickafin = m*0.5*(vx**2.0 + vy**2.0 + vz**2.0)

ans = (kinetickainit - kinetickafin)/kinetickainit
print(ans)
#print (kinetickainit - kinetickafin)/kinetickainit

d = 1e9
fig = plt.figure() #graph
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('auto')
ax.grid(False)
plt.xlabel("$x[R_T]$")
plt.ylabel("$y[R_T]$")
ax.set_zlabel("$z[R_T]$")
plt.axis('on')
#ax.set_xlim3d(-6, 6) #change inf needed
#ax.set_ylim3d(-6, 6)
#ax.set_zlim3d(-6, 6)
plt.plot(xx/d, yy/d, zz/d, color = 'cyan')
plt.show()
# Out:
# [2.38856269e-13]

# %%
#2D representation
fig_xz = plt.figure()
ax_xz = fig_xz.add_subplot(111)
plt.xlabel("$x[R_T]$")
plt.ylabel("$z[R_T]$")
ax_xz.grid(True)

ax_xz.plot(xx/d, zz/d, color='cyan')
plt.show()

fig_xy = plt.figure()
ax_xy = fig_xy.add_subplot(111)
plt.xlabel("$x[R_T]$")
plt.ylabel("$y[R_T]$")
ax_xy.grid(True)

ax_xy.plot(xx/d, yy/d, color='cyan')
plt.show()

# %% [raw]
# import plotly.graph_objs as go
#
# fig = go.Figure(data=[go.Scatter3d(x=xx, y=yy, z=zz, mode='lines', name='parametric curve for protons')])
#
# fig.show()

# %% [markdown]
# ### For electrons

# %%
import numpy as np
import matplotlib.pyplot as plt
import PVREDNOSTI, IZLAZ, DEFPOLJA # Input files (PVREDNOSTI: initial conditions are there; IZLAZ: output to be shown in graph is there; DEFPOLJA: field definitions are there)

#############################
# Input parameters
#############################

N = 1 # we use only one particle

T_sim = 300.0 # simulation duration [s]
dt = 0.01 # time step
T_smp = 5.0 # times step for graphical representation

##########################
# definitions of variables
##########################

l = 0
q = np.zeros(N)
m = np.zeros(N)
x = np.zeros(N)
y = np.zeros(N)
z = np.zeros(N)
vx = np.zeros(N)
vy = np.zeros(N)
vz = np.zeros(N)
EPx = 0.0
EPy = 0.0
EPz = 0.0
BPx = 0.0
BPy = 0.0
BPz = 0.0   
pomx = np.zeros(N)
pomy = np.zeros(N)
pomz = np.zeros(N)

#################
# initialization
#################

t = 0.0
 
q, m, x, y, z, vx, vy, vz = PVREDNOSTI.puslovi_e(N, np)

BPx, BPy, BPz, EPx, EPy, EPz = DEFPOLJA.const_B(x, y, z, t)

fig, sp1, sp2 = IZLAZ.init_plots(plt)


xx = np.zeros(60001)
yy = np.zeros(60001)
zz = np.zeros(60001)

ii = 0

xx[ii] = x
yy[ii] = y
zz[ii] = z


###############
# Main loop
###############
# See
# https://aapt.scitation.org/doi/10.1119/10.0001876
# https://arxiv.org/abs/2008.11810
# https://www.compadre.org/PICUP/resources/Numerical-Integration/

kinetickainit = m*0.5*(vx**2.0 + vy**2.0 + vz**2.0)

while t < (T_sim - dt):

    t = t + dt

    pomx = vx + ((q*dt*0.5/m)*(EPx + (vy*BPz) - (BPy*vz)))
    pomy = vy + ((q*dt*0.5/m)*(EPy + (vz*BPx) - (BPz*vx)))
    pomz = vz + ((q*dt*0.5/m)*(EPz + (vx*BPy) - (BPx*vy)))

    x = x + (pomx*dt)
    y = y + (pomy*dt)
    z = z + (pomz*dt)
    

    BPx, BPy, BPz, EPx, EPy, EPz = DEFPOLJA.const_B(x, y, z, t)
    #print(x)
    pomx = pomx + ((q*dt*0.5/m)*EPx)
    pomy = pomy + ((q*dt*0.5/m)*EPy)
    pomz = pomz + ((q*dt*0.5/m)*EPz)

    vx = ((1.0 + (((q*dt*0.5/m)**2.0)*(BPx**2.0 + BPy**2.0 + BPz**2.0)))**(-1.0))*(pomx + ((q*dt*0.5/m)*(pomy*BPz - pomz*BPy)) + (((q*dt*0.5/m)**2.0)*BPx*(pomx*BPx + pomy*BPy + pomz*BPz)))
     
    #print(vx)    
    vy = ((1.0 + (((q*dt*0.5/m)**2.0)*(BPx**2.0 + BPy**2.0 + BPz**2.0)))**(-1.0))*(pomy + ((q*dt*0.5/m)*(pomz*BPx - pomx*BPz)) + (((q*dt*0.5/m)**2.0)*BPy*(pomx*BPx + pomy*BPy + pomz*BPz))) 

    vz = ((1.0 + (((q*dt*0.5/m)**2.0)*(BPx**2.0 + BPy**2.0 + BPz**2.0)))**(-1.0))*(pomz + ((q*dt*0.5/m)*(pomx*BPy - pomy*BPx)) + (((q*dt*0.5/m)**2.0)*BPz*(pomx*BPx + pomy*BPy + pomz*BPz)))

    ii = ii + 1
    xx[ii] = x
    yy[ii] = y
    zz[ii] = z 
    ###################################
    # show in graph
    ###################################

    l += 1

    if l*dt >= T_smp:

        l = 0.0
        IZLAZ.write_plots(sp1, sp2, plt, x, y, z, t, T_sim) # show in real time

kinetickafin = m*0.5*(vx**2.0 + vy**2.0 + vz**2.0)

ans = abs(kinetickainit - kinetickafin)/kinetickainit
print(ans)
#print (kinetickainit - kinetickafin)/kinetickainit

d = 1e9
fig = plt.figure() #graph
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('auto')
ax.grid(False)
plt.xlabel("$x[R_T]$")
plt.ylabel("$y[R_T]$")
ax.set_zlabel("$z[R_T]$")
plt.axis('on')
#ax.set_xlim3d(-70, 70) #change inf needed
#ax.set_ylim3d(-70, 70)
#ax.set_zlim3d(-70, 70)
plt.plot(xx/d, yy/d, zz/d, color = 'gold')
plt.show()
# Out:
# [1.54506428e-12]

# %%
fig_xz = plt.figure()
ax_xz = fig_xz.add_subplot(111)
plt.xlabel("$x[R_T]$")
plt.ylabel("$z[R_T]$")
ax_xz.grid(True)

ax_xz.plot(xx/d, zz/d, color='gold')
plt.show()

fig_xy = plt.figure()
ax_xy = fig_xy.add_subplot(111)
plt.xlabel("$x[R_T]$")
plt.ylabel("$y[R_T]$")
ax_xy.grid(True)

ax_xy.plot(xx/d, yy/d, color='gold')
plt.show()

# %% [markdown]
# ### For alpha particles

# %%
import numpy as np
import matplotlib.pyplot as plt
import PVREDNOSTI, IZLAZ, DEFPOLJA # Input files (PVREDNOSTI: initial conditions are there; IZLAZ: output to be shown in graph is there; DEFPOLJA: field definitions are there)

#############################
# Input parameters
#############################

N = 1 # we use only one particle

T_sim = 1000.0 # simulation duration [s]
dt = 0.1 # time step
T_smp = 5.0 # times step for graphical representation

##########################
# definitions of variables
##########################

l = 0
q = np.zeros(N)
m = np.zeros(N)
x = np.zeros(N)
y = np.zeros(N)
z = np.zeros(N)
vx = np.zeros(N)
vy = np.zeros(N)
vz = np.zeros(N)
EPx = 0.0
EPy = 0.0
EPz = 0.0
BPx = 0.0
BPy = 0.0
BPz = 0.0   
pomx = np.zeros(N)
pomy = np.zeros(N)
pomz = np.zeros(N)

#################
# initialization
#################

t = 0.0
 
q, m, x, y, z, vx, vy, vz = PVREDNOSTI.puslovi_alpha(N, np)

BPx, BPy, BPz, EPx, EPy, EPz = DEFPOLJA.const_B(x, y, z, t)

fig, sp1, sp2 = IZLAZ.init_plots(plt)


xx = np.zeros(60001)
yy = np.zeros(60001)
zz = np.zeros(60001)

ii = 0

xx[ii] = x
yy[ii] = y
zz[ii] = z


###############
# Main loop
###############
# See
# https://aapt.scitation.org/doi/10.1119/10.0001876
# https://arxiv.org/abs/2008.11810
# https://www.compadre.org/PICUP/resources/Numerical-Integration/

kinetickainit = m*0.5*(vx**2.0 + vy**2.0 + vz**2.0)

while t < (T_sim - dt):

    t = t + dt	

    pomx = vx + ((q*dt*0.5/m)*(EPx + (vy*BPz) - (BPy*vz)))
    pomy = vy + ((q*dt*0.5/m)*(EPy + (vz*BPx) - (BPz*vx)))
    pomz = vz + ((q*dt*0.5/m)*(EPz + (vx*BPy) - (BPx*vy)))

    x = x + (pomx*dt)
    y = y + (pomy*dt)
    z = z + (pomz*dt)
    

    BPx, BPy, BPz, EPx, EPy, EPz = DEFPOLJA.const_B(x, y, z, t)
    #print(x)
    pomx = pomx + ((q*dt*0.5/m)*EPx)
    pomy = pomy + ((q*dt*0.5/m)*EPy)
    pomz = pomz + ((q*dt*0.5/m)*EPz)

    vx = ((1.0 + (((q*dt*0.5/m)**2.0)*(BPx**2.0 + BPy**2.0 + BPz**2.0)))**(-1.0))*(pomx + ((q*dt*0.5/m)*(pomy*BPz - pomz*BPy)) + (((q*dt*0.5/m)**2.0)*BPx*(pomx*BPx + pomy*BPy + pomz*BPz)))

    vy = ((1.0 + (((q*dt*0.5/m)**2.0)*(BPx**2.0 + BPy**2.0 + BPz**2.0)))**(-1.0))*(pomy + ((q*dt*0.5/m)*(pomz*BPx - pomx*BPz)) + (((q*dt*0.5/m)**2.0)*BPy*(pomx*BPx + pomy*BPy + pomz*BPz))) 

    vz = ((1.0 + (((q*dt*0.5/m)**2.0)*(BPx**2.0 + BPy**2.0 + BPz**2.0)))**(-1.0))*(pomz + ((q*dt*0.5/m)*(pomx*BPy - pomy*BPx)) + (((q*dt*0.5/m)**2.0)*BPz*(pomx*BPx + pomy*BPy + pomz*BPz)))

    ii = ii + 1
    xx[ii] = x
    yy[ii] = y
    zz[ii] = z 
    ###################################
    # show in graph
    ###################################

    l += 1

    if l*dt >= T_smp:

        l = 0.0
        IZLAZ.write_plots(sp1, sp2, plt, x, y, z, t, T_sim) # show in real time

kinetickafin = m*0.5*(vx**2.0 + vy**2.0 + vz**2.0)

ans = (kinetickainit - kinetickafin)/kinetickainit
print(ans)
#print (kinetickainit - kinetickafin)/kinetickainit

d = 1e9
fig = plt.figure() #graph
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('auto')
ax.grid(False)
plt.xlabel("$x[R_T]$")
plt.ylabel("$y[R_T]$")
ax.set_zlabel("$z[R_T]$")
plt.axis('on')
#ax.set_xlim3d(-70, 70) #change if needed
#ax.set_ylim3d(-70, 70)
#ax.set_zlim3d(-70, 70)
plt.plot(xx/d, yy/d, zz/d, color = 'magenta')
plt.show()
# Out:
# [2.54480913e-15]

# %%
fig_xz = plt.figure()
ax_xz = fig_xz.add_subplot(111)
plt.xlabel("$x[R_T]$")
plt.ylabel("$z[R_T]$")
ax_xz.grid(True)

ax_xz.plot(xx/d, zz/d, color='magenta')
plt.show()

fig_xy = plt.figure()
ax_xy = fig_xy.add_subplot(111)
plt.xlabel("$x[R_T]$")
plt.ylabel("$y[R_T]$")
ax_xy.grid(True)

ax_xy.plot(xx/d, yy/d, color='magenta')
plt.show()

# %% [raw]
# import plotly.graph_objs as go
#
# fig = go.Figure(data=[go.Scatter3d(x=xx, y=yy, z=zz, mode='lines', name='parametric curve for alpha particles')])
#
# fig.show()
